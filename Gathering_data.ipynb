# %%
# !pip install bing-image-downloader
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# making a new folder as images
# !mkdir images

# %%
from bing_image_downloader import downloader

# %%
# downloading pretty red rose from the bing
downloader.download('pretty red rose', limit=100,  output_dir='images', adult_filter_off=True)
# Out:
# [%] Downloading Images to D:\Learning\Image Classification\Data Collection\images\pretty red rose
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/b1/1a/37/b11a370b09c612223bd558913764981a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.publicdomainpictures.net/pictures/40000/velka/beautiful-red-rose.jpg
# [!] Issue getting: http://www.publicdomainpictures.net/pictures/40000/velka/beautiful-red-rose.jpg
# [!] Error:: HTTP Error 503: Service Temporarily Unavailable
# [%] Downloading Image #2 from http://thewowstyle.com/wp-content/uploads/2015/01/Cropped_Small_Red_Rose1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://4.bp.blogspot.com/-E-vZ-JfLbT8/UEykiXBOwYI/AAAAAAAAAhA/TABTfb3y5q4/s1600/red+rose.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://1.bp.blogspot.com/-LF3ziTasavg/T9oF-wduDoI/AAAAAAAAAlI/7Otp-W5jqyU/s1600/Pretty_red_rose.jpg
# ...

# %%
# downloading rugby ball from the bing
downloader.download('rugby ball leather', limit=100,  output_dir='images', adult_filter_off=True)
# Out:
# [%] Downloading Images to D:\Learning\Image Classification\Data Collection\images\rugby ball leather
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.shopify.com/s/files/1/0788/5979/products/mvp-leather-balls-heritage-leather-rugby-ball-1_2356x.jpg?v=1550134680
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.footballfanatics.com/england-rugby/england-heritage-leather-rugby-ball_ss4_p-11915081+u-i1yzm7ua8msrxcp06yj2+v-79898d6efb7f4d5187711b139f60f3f8.jpg?_hv=1
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.shopify.com/s/files/1/0788/5979/products/mvp-leather-balls-deluxe-leather-rugby-ball-1_2356x.jpg?v=1551767452
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.shopify.com/s/files/1/0788/5979/products/mvp-leather-balls-heritage-leather-rugby-ball-2_2048x.jpg?v=1561783613
# [%] File Downloaded !
#
# ...

# %%
# downloading ice cream cone from the bing
downloader.download('ice cream cone', limit=100,  output_dir='images', adult_filter_off=True)
# Out:
# [%] Downloading Images to D:\Learning\Image Classification\Data Collection\images\ice cream cone
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.camdenac.com/wp-content/uploads/2017/05/7-scoop-ice-cream-cone.jpg
# [Error]Invalid image, not saving http://www.camdenac.com/wp-content/uploads/2017/05/7-scoop-ice-cream-cone.jpg
#
# [!] Issue getting: http://www.camdenac.com/wp-content/uploads/2017/05/7-scoop-ice-cream-cone.jpg
# [!] Error:: Invalid image, not saving http://www.camdenac.com/wp-content/uploads/2017/05/7-scoop-ice-cream-cone.jpg
#
# [%] Downloading Image #1 from http://www.kitcheninnovationsinc.com/wp-content/uploads/2014/07/J218DISP-Ice-Cream.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://2.bp.blogspot.com/-F3gVYgswpwk/TaO0wEm2ybI/AAAAAAAACBk/-oWSEnlMOSo/s320/ice+cream+cone.jpg
# [%] File Downloaded !
#
# ...

# %%
# to see the execution time of the cell
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
# time: 0 ns (started: 2023-01-06 11:17:45 +05:30)
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
